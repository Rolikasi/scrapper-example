# %%
import pandas as pd
import re
import requests
from lxml import html
import sys

# %%
class Scrapper:
    
    def __init__(self, source, link_pattern, xpath, df, max_while = 4, max_links = 10):
        self.source = source
        self.link_pattern = link_pattern
        self.xpath = xpath
        self.df = df
        self.max_while = max_while
        self.max_links = max_links
        self.link_storage = []
        self.link_history = []
    
    def scrape(self, seed_link):
        self.link_storage.append(seed_link)
        print('Put link into seed link storage')
        i = 0
        while True:
            links_list_length = len(self.link_storage)
            print('Entered while cycle')
            links = self.link_storage.copy()
            for link in links:
                print('Entered for cycle')
                if link not in self.link_history:
                    seed_page = self.load(link)
                    print('Tried to load: ' + link)
                    self.link_history.append(link)
                    if seed_page:
                        print('Loaded: ' + link)
                        if self.is_needed(link):
                            print('Link is needed: ' + link)
                            self.extract_info(seed_page)
                            print('Info extracted')
                        self.extract_links(seed_page)
                        print('Links extracted')
                if self.df.shape[0] > self.max_links:
                    break
            if links_list_length == len(self.link_storage):
                i += 1
            if self.df.shape[0] > self.max_links or i > self.max_while:
                break
        #    self.scrape(self.link_storage)
        return self.df
        
    
    def extract_links(self, page):
        pattern = self.source + '[a-z0-9\-\_\.\/]+'
        links = re.findall(pattern, page.text)
        for link in links:
            if not link in self.link_storage:
                self.link_storage.append(link)
    
    def load(self, link):
        response = requests.get(link)            
        return response
    
    def extract_info(self, page):
        for path in self.xpath:
            tree = html.fromstring(page.content.decode('UTF-8'))
            result = tree.xpath(path)   
            
            print('find this: ' + path + ' in', end = ' ')
            print (self.xpath)
            
            self.df = self.df.append(pd.DataFrame(result), ignore_index=True) #нужно создать в цикле новую df из results и добавлять ее к общей df
            
            print (path + ' added')
            #return result
    
    def is_needed(self, link):
        return bool(re.search(self.link_pattern, link))

# %%
df = pd.DataFrame(columns=['title','author', 'lead'])          #На сайте клоопа расположение, описание и наличие lead часто менялись

scrapper_kloop = Scrapper('https://kloop.kg', 
                          '/blog/',
                          xpath = ['//header/h1/text()',  '//header/div/div/a/text()', '//h4/strong/text()'],                   #сделать список xpath в [], '//header/div/div/a', '//footer/div/ul
                          df=df)


#xpath = ['title' : '//header/h1/text()', 'author' : '//header/div/div/a',   'tag' :'//footer/div/ul'],

# %%
df = scrapper_kloop.scrape ('https://kloop.kg')
# Out:
# Put link into seed link storage
# Entered while cycle
# Entered for cycle
# Tried to load: https://kloop.kg
# Loaded: https://kloop.kg
# Links extracted
# Entered while cycle
# Entered for cycle
# Entered for cycle
# Tried to load: https://kloop.kg/xmlrpc.php
# Loaded: https://kloop.kg/xmlrpc.php
# Links extracted
# Entered for cycle
# Tried to load: https://kloop.kg/wp-content/uploads/2014/08/kloop_favicon.png
# Loaded: https://kloop.kg/wp-content/uploads/2014/08/kloop_favicon.png
# Links extracted
# Entered for cycle
# Tried to load: https://kloop.kg/
# Loaded: https://kloop.kg/
# Links extracted
# Entered for cycle
# Tried to load: https://kloop.kg/feed/
# Loaded: https://kloop.kg/feed/
# Links extracted
# Entered for cycle
# Tried to load: https://kloop.kg/comments/feed/
# Loaded: https://kloop.kg/comments/feed/
# Links extracted
# Entered for cycle
# Tried to load: https://kloop.kg/wp-content/plugins/chained-quiz/css/main.css
# Loaded: https://kloop.kg/wp-content/plugins/chained-quiz/css/main.css
# Links extracted
# Entered for cycle
# Tried to load: https://kloop.kg/wp-content/plugins/contact-form-7/includes/css/styles.css
# Loaded: https://kloop.kg/wp-content/plugins/contact-form-7/includes/css/styles.css
# Links extracted
# Entered for cycle
# Tried to load: https://kloop.kg/wp-content/uploads/custom-css/custom-css-1540807138.min.css
# Loaded: https://kloop.kg/wp-content/uploads/custom-css/custom-css-1540807138.min.css
# Links extracted
# Entered for cycle
# Tried to load: https://kloop.kg/wp-content/plugins/easy-social-share-buttons3/assets/css/essb-native-skinned.min.css
# Loaded: https://kloop.kg/wp-content/plugins/easy-social-share-buttons3/assets/css/essb-native-skinned.min.css
# Links extracted
# Entered for cycle
# Tried to load: https://kloop.kg/wp-content/plugins/easy-social-share-buttons3/assets/css/font-awesome.min.css
# Loaded: https://kloop.kg/wp-content/plugins/easy-social-share-buttons3/assets/css/font-awesome.min.css
# Links extracted
# Entered for cycle
# Tried to load: https://kloop.kg/wp-content/plugins/easy-social-share-buttons3/assets/css/tiny-retina/easy-social-share-buttons.min.css
# Loaded: https://kloop.kg/wp-content/plugins/easy-social-share-buttons3/assets/css/tiny-retina/easy-social-share-buttons.min.css
# Links extracted
# Entered for cycle
# Tried to load: https://kloop.kg/wp-content/plugins/easy-social-share-buttons3/assets/css/essb-mobile.min.css
# Loaded: https://kloop.kg/wp-content/plugins/easy-social-share-buttons3/assets/css/essb-mobile.min.css
# Links extracted
# Entered for cycle
# Tried to load: https://kloop.kg/wp-content/plugins/easy-social-share-buttons3/lib/modules/click-to-tweet/assets/css/styles.css
# Loaded: https://kloop.kg/wp-content/plugins/easy-social-share-buttons3/lib/modules/click-to-tweet/assets/css/styles.css
# Links extracted
# Entered for cycle
# Tried to load: https://kloop.kg/wp-content/plugins/elementor/assets/lib/eicons/css/elementor-icons.min.css
# Loaded: https://kloop.kg/wp-content/plugins/elementor/assets/lib/eicons/css/elementor-icons.min.css
# Links extracted
# Entered for cycle
# Tried to load: https://kloop.kg/wp-content/plugins/js_composer/assets/lib/bower/font-awesome/css/font-awesome.min.css
# Loaded: https://kloop.kg/wp-content/plugins/js_composer/assets/lib/bower/font-awesome/css/font-awesome.min.css
# Links extracted
# Entered for cycle
# Tried to load: https://kloop.kg/wp-content/plugins/elementor/assets/lib/animations/animations.min.css
# Loaded: https://kloop.kg/wp-content/plugins/elementor/assets/lib/animations/animations.min.css
# Links extracted
# Entered for cycle
# Tried to load: https://kloop.kg/wp-content/plugins/elementor/assets/css/frontend.min.css
# Loaded: https://kloop.kg/wp-content/plugins/elementor/assets/css/frontend.min.css
# Links extracted
# Entered for cycle
# Tried to load: https://kloop.kg/wp-content/plugins/elementor-pro/assets/css/frontend.min.css
# Loaded: https://kloop.kg/wp-content/plugins/elementor-pro/assets/css/frontend.min.css
# Links extracted
# Entered for cycle
# Tried to load: https://kloop.kg/wp-content/uploads/elementor/css/global.css
# Loaded: https://kloop.kg/wp-content/uploads/elementor/css/global.css
# Links extracted
# Entered for cycle
# Tried to load: https://kloop.kg/wp-content/uploads/elementor/css/post-139093.css
# Loaded: https://kloop.kg/wp-content/uploads/elementor/css/post-139093.css
# Links extracted
# Entered for cycle
# Tried to load: https://kloop.kg/wp-content/plugins/js_composer/assets/css/js_composer.min.css
# Loaded: https://kloop.kg/wp-content/plugins/js_composer/assets/css/js_composer.min.css
# Links extracted
# Entered for cycle
# Tried to load: https://kloop.kg/wp-content/themes/
# Loaded: https://kloop.kg/wp-content/themes/
# Links extracted
# Entered for cycle
# Tried to load: https://kloop.kg/wp-includes/js/jquery/jquery.js
# Loaded: https://kloop.kg/wp-includes/js/jquery/jquery.js
# Links extracted
# Entered for cycle
# Tried to load: https://kloop.kg/wp-includes/js/jquery/jquery-migrate.min.js
# Loaded: https://kloop.kg/wp-includes/js/jquery/jquery-migrate.min.js
# Links extracted
# Entered for cycle
# Tried to load: https://kloop.kg/wp-content/plugins/google-analytics-dashboard-for-wp/front/js/tracking-analytics-events.js
# Loaded: https://kloop.kg/wp-content/plugins/google-analytics-dashboard-for-wp/front/js/tracking-analytics-events.js
# Links extracted
# Entered for cycle
# Tried to load: https://kloop.kg/wp-content/plugins/chained-quiz/js/common.js
# Loaded: https://kloop.kg/wp-content/plugins/chained-quiz/js/common.js
# Links extracted
# Entered for cycle
# Tried to load: https://kloop.kg/wp-json/
# Loaded: https://kloop.kg/wp-json/
# Links extracted
# Entered for cycle
# Tried to load: https://kloop.kg/wp-includes/wlwmanifest.xml
# Loaded: https://kloop.kg/wp-includes/wlwmanifest.xml
# Links extracted
# Entered for cycle
# Tried to load: https://kloop.kg/wp-json/oembed/1.0/embed
# Entered for cycle
# Tried to load: https://kloop.kg/wp-content/plugins/js_composer/assets/css/vc_lte_ie9.min.css
# Loaded: https://kloop.kg/wp-content/plugins/js_composer/assets/css/vc_lte_ie9.min.css
# Links extracted
# Entered for cycle
# Tried to load: https://kloop.kg/news
# Loaded: https://kloop.kg/news
# Links extracted
# Entered for cycle
# Tried to load: https://kloop.kg/features
# Loaded: https://kloop.kg/features
# Links extracted
# Entered for cycle
# Tried to load: https://kloop.kg/o-nas/
# Loaded: https://kloop.kg/o-nas/
# Links extracted
# Entered for cycle
# Tried to load: https://kloop.kg/blog/2018/06/21/zapisyvajtes-letnyaya-shkola-zhurnalistiki-ot-bektura-iskendera-s-posleduyushhej-stazhirovkoj-v-kloope/
# Loaded: https://kloop.kg/blog/2018/06/21/zapisyvajtes-letnyaya-shkola-zhurnalistiki-ot-bektura-iskendera-s-posleduyushhej-stazhirovkoj-v-kloope/
# Link is needed: https://kloop.kg/blog/2018/06/21/zapisyvajtes-letnyaya-shkola-zhurnalistiki-ot-bektura-iskendera-s-posleduyushhej-stazhirovkoj-v-kloope/
# find this: //header/h1/text() in ['//header/h1/text()', '//header/div/div/a/text()', '//h4/strong/text()']
# //header/h1/text() added
# find this: //header/div/div/a/text() in ['//header/h1/text()', '//header/div/div/a/text()', '//h4/strong/text()']
# //header/div/div/a/text() added
# find this: //h4/strong/text() in ['//header/h1/text()', '//header/div/div/a/text()', '//h4/strong/text()']
# //h4/strong/text() added
# Info extracted
# Links extracted
# Entered for cycle
# Tried to load: https://kloop.kg/kyrgyz-space-program-for-girls/
# Loaded: https://kloop.kg/kyrgyz-space-program-for-girls/
# Links extracted
# Entered for cycle
# Tried to load: https://kloop.kg/factchecking/
# Loaded: https://kloop.kg/factchecking/
# Links extracted
# Entered for cycle
# Tried to load: https://kloop.kg/wp-content/uploads/2017/01/kloop_transparent_site.png
# Loaded: https://kloop.kg/wp-content/uploads/2017/01/kloop_transparent_site.png
# Links extracted
# Entered for cycle
# Tried to load: https://kloop.kg/wp-content/uploads/2013/10/
# Entered for cycle
# Tried to load: https://kloop.kg/wp-content/uploads/2011/08/logo.png
# Loaded: https://kloop.kg/wp-content/uploads/2011/08/logo.png
# Links extracted
# Entered for cycle
# Tried to load: https://kloop.kg/blog/2018/06/13/tadzhikistan-milliony-v-brachnoj-korzine/
# Loaded: https://kloop.kg/blog/2018/06/13/tadzhikistan-milliony-v-brachnoj-korzine/
# Link is needed: https://kloop.kg/blog/2018/06/13/tadzhikistan-milliony-v-brachnoj-korzine/
# find this: //header/h1/text() in ['//header/h1/text()', '//header/div/div/a/text()', '//h4/strong/text()']
# //header/h1/text() added
# find this: //header/div/div/a/text() in ['//header/h1/text()', '//header/div/div/a/text()', '//h4/strong/text()']
# //header/div/div/a/text() added
# find this: //h4/strong/text() in ['//header/h1/text()', '//header/div/div/a/text()', '//h4/strong/text()']
# //h4/strong/text() added
# Info extracted
# Links extracted
# Entered for cycle
# Tried to load: https://kloop.kg/wp-content/uploads/2018/06/
# Entered for cycle
# Tried to load: https://kloop.kg/blog/2018/11/05/tsik-lishil-shadieva-deputatskogo-kresla-po-ego-zhe-prosbe-sam-politik-otritsaet-chto-prosil-ob-etom/
# Loaded: https://kloop.kg/blog/2018/11/05/tsik-lishil-shadieva-deputatskogo-kresla-po-ego-zhe-prosbe-sam-politik-otritsaet-chto-prosil-ob-etom/
# Link is needed: https://kloop.kg/blog/2018/11/05/tsik-lishil-shadieva-deputatskogo-kresla-po-ego-zhe-prosbe-sam-politik-otritsaet-chto-prosil-ob-etom/
# find this: //header/h1/text() in ['//header/h1/text()', '//header/div/div/a/text()', '//h4/strong/text()']
# //header/h1/text() added
# find this: //header/div/div/a/text() in ['//header/h1/text()', '//header/div/div/a/text()', '//h4/strong/text()']
# //header/div/div/a/text() added
# find this: //h4/strong/text() in ['//header/h1/text()', '//header/div/div/a/text()', '//h4/strong/text()']
# //h4/strong/text() added
# Info extracted
# Links extracted
# Entered for cycle
# Tried to load: https://kloop.kg/wp-content/uploads/2018/11/
# Entered for cycle
# Tried to load: https://kloop.kg/blog/2018/11/03/tsifra-dnya-ugolovnoe-delo-protiv-byvshego-kyrgyzskogo-deputata-asylbeka-uulu-sostoit-iz-126-tomov/
# Loaded: https://kloop.kg/blog/2018/11/03/tsifra-dnya-ugolovnoe-delo-protiv-byvshego-kyrgyzskogo-deputata-asylbeka-uulu-sostoit-iz-126-tomov/
# Link is needed: https://kloop.kg/blog/2018/11/03/tsifra-dnya-ugolovnoe-delo-protiv-byvshego-kyrgyzskogo-deputata-asylbeka-uulu-sostoit-iz-126-tomov/
# find this: //header/h1/text() in ['//header/h1/text()', '//header/div/div/a/text()', '//h4/strong/text()']
# //header/h1/text() added
# find this: //header/div/div/a/text() in ['//header/h1/text()', '//header/div/div/a/text()', '//h4/strong/text()']
# //header/div/div/a/text() added
# find this: //h4/strong/text() in ['//header/h1/text()', '//header/div/div/a/text()', '//h4/strong/text()']
# //h4/strong/text() added
# Info extracted
# Links extracted
# Entered for cycle
# Tried to load: https://kloop.kg/blog/2018/10/30/odnim-kadrom-sooronbaj-zheenbekov-pozhal-ruku-chempionu-ufc-habibu-nurmagomedovu/
# Loaded: https://kloop.kg/blog/2018/10/30/odnim-kadrom-sooronbaj-zheenbekov-pozhal-ruku-chempionu-ufc-habibu-nurmagomedovu/
# Link is needed: https://kloop.kg/blog/2018/10/30/odnim-kadrom-sooronbaj-zheenbekov-pozhal-ruku-chempionu-ufc-habibu-nurmagomedovu/
# find this: //header/h1/text() in ['//header/h1/text()', '//header/div/div/a/text()', '//h4/strong/text()']
# //header/h1/text() added
# find this: //header/div/div/a/text() in ['//header/h1/text()', '//header/div/div/a/text()', '//h4/strong/text()']
# //header/div/div/a/text() added
# find this: //h4/strong/text() in ['//header/h1/text()', '//header/div/div/a/text()', '//h4/strong/text()']
# //h4/strong/text() added
# Info extracted
# Links extracted

# %%
df
# Out:
#    title author lead                                                  0
# 0    NaN    NaN  NaN  Записывайтесь! Летняя школа журналистики от Бе...
# 1    NaN    NaN  NaN                                    Бектур Искендер
# 2    NaN    NaN  NaN            ТАДЖИКИСТАН: МИЛЛИОНЫ В БРАЧНОЙ КОРЗИНЕ
# 3    NaN    NaN  NaN                                              OCCRP
# 4    NaN    NaN  NaN  ЦИК лишил Шадиева депутатского кресла по его ж...
# 5    NaN    NaN  NaN                                     Рустам Халимов
# 6    NaN    NaN  NaN  Бывший депутат кыргызского парламента Аскарбек...
# 7    NaN    NaN  NaN  Цифра дня: Уголовное дело против бывшего кыргы...
# 8    NaN    NaN  NaN                                    Айдай Иргебаева
# 9    NaN    NaN  NaN  Одним кадром: Сооронбай Жээнбеков и чемпион UF...
# 10   NaN    NaN  NaN                                    Айдай Иргебаева

# %%
scrapper_kloop.load('https://kloop.kg/blog/2018/11/01/isa-omurkulov-bolshe-ne-chlen-sdpk-no-ostaetsya-liderom-ee-parlamentskoj-fraktsii-chto-proishodit/')

# %%
for scrapper_kloop.path in scrapper_kloop.xpath:
    print(scrapper_kloop.path)
# Out:
# //header/div/div/a/text()
# //footer/div/ul/text()

# %%
scrapper_kloop.df.shape
# Out:
# (0, 3)

# %%
scrapper_kloop.df.columns
# Out:
# Index(['title', 'author', 'tag'], dtype='object')

# %%
scrapper_kloop.xpath [0]
# Out:
# '//header/h1/text()'

# %%
scrapper_kloop.s2
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-42-3c61d365a92c> in <module>
# ----> 1 scrapper_kloop.s2
#
# AttributeError: 'Scrapper' object has no attribute 's2'
